# %% [markdown]
# # Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 18 points in total.  15 points in the report.  3 points in the video summary of your report for a non-technical audience.
#
# For the report:
# - Each Developing  => -0.5 pts
# - Each Unsatisfactory/Missing => -1 pts
#   - until the score is 0
#
# For the video:
# - Developing  => -1.5 pts
# - Unsatisfactory/Missing => -3 pts
#
# |                                                                                    | Unsatisfactory                                                                                                                                                                                                                                                                                      | Developing                                                                                                                                                                                                                                                                                                                          | Proficient                                                                                                                                                                                                                                                    | Exellent                                                                                                                                                                                                                                                                                                                                                          |
# | ---------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Title & abstract                                                                   | Title or abstract is confusing or fails to offer important details about the question, variables, context, or methods of the project.                                                                                                                                                               | Title or abstract lacks relevance or fails to offer appropriate details about the question, variables, context, or methods of the project.                                                                                                                                                                                          | Title and abstract are relevant, offering sufficient details about the research project.                                                                                                                                                                      | Title and abstract are informative, succinct, and clear. It offers specific details about the question, variables, context, and proposed methods of the study.                                                                                                                                                                                                    |
# | Background                                                                         | Did not have at least 3 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                           | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                           | Key research components were connected to relevant, reliable literature.                                                                                                                                                                                      | Narrative integrates critical and logical details from the peer-reviewed or other professional research literature. Each key research component is grounded to the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                                                       |
# | Research question & hypothesis                                                     | Research issue remains unclear. The research purpose, questions, hypotheses, definitions or variables and controls are still largely undefined, or when they are are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Research issue is identified, but statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem related to the chemical sciences. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported from the research and theoretical literature. All elements are mutually supportive. |
# | Data description                                                                   | Did not have references to relevant data sources for this problem. Did not describe the data obtained at those sources                                                                                                                                                                              | A key data source was not referenced or described in satisfactory level of detail                                                                                                                                                                                                                                                   | All relevant data sources were referenced and described in terms of their key variables and size                                                                                                                                                              | Multiple data sources for each aspect of the project, All data sources are fully described and referenced. The details of the descriptions also make it clear how they support the needs ot the project.                                                                                                                                                          |
# | Data wrangling                                                                     | Data obviously not tidy and not clean. Or even if they are clean/tidy, there was no demonstration of that fact                                                                                                                                                                                      | Data has some minor problems with tidiness or cleanliness. Potentially these are not problems but it wasn't fully demonstrated to be the case in the code                                                                                                                                                                           | Data are made tidy and clean, or are clearly demonstrated to be so from download                                                                                                                                                                              | Data wrangling is complete, but also particularly thoroughly done for a very tough case. Often free text parsing is a bear like this, and doing it well can mean a million edge cases.                                                                                                                                                                            |
# | Data visualizations                                                                | Many plots don't capture useful information, or their display of information is difficult to understand.. Legends, labels, axes, titles, captions, etc of many plots may be poor or missing. Figures are not referenced in the main text.                                                           | Most plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are mostly legible and adequately describe the content of the figure. Most figures are referenced or explained inside the main text and not just left hanging.                                                                   | Plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are clearly legible and adequately describe the content of the figure. Figures are referenced or explained inside the main text and not just left hanging.      | Plots are beautiful and information dense. Legends, labels, axes, titles, captions, etc clearly describe the content of the figure. Figures are well integrated with the text.                                                                                                                                                                                    |
# | Data analysis and results                                                          | Lacks any metrics or at least metrics that are relevant to the problem                                                                                                                                                                                                                              | Some metrics selected are not appropriate for the problem or the metrics selected are not described sufficiently                                                                                                                                                                                                                    | All metrics described are appropriate and and described sufficiently                                                                                                                                                                                          | The metrics are described clearly and succinctly. Their appropriateness for addressing the research problem is clearly described.                                                                                                                                                                                                                                 |
# | Ethics                                                                             | Only tries a baseline model, never advances to proper model/hyper-parameter selection                                                                                                                                                                                                               | Only investigates one minimal aspect of their problem, e.g. just did a single hyperparameter selection on a single model                                                                                                                                                                                                            | Does a good model/hyper-parameter selection. Only attempts minimal secondary analysis                                                                                                                                                                         | Does a good model/hyper-parameter selection. Performs multiple secondary analysis such as learning curves, heat maps looking at where in the parameter space things are good/bad, uses statistical testing                                                                                                                                                        |
# | Conclusion and discussion                                                          | Doesn't have a narrative/conclusions of what the report accomplished. Or very minimal conclusions, like "X was best" without anything else                                                                                                                                                          | Has narrative/conclusions, but it feels perfunctory and lacks context. Especially if the limitations and ethics sections are largely junk or missing                                                                                                                                                                                | Properly recapitulates the results and provides context for them. Has a sense of the limitatins and ethical issues.                                                                                                                                           | Clearly recapitulates the results and provides context, including the literature/background Has a sense of what to do next, and has good explorations of the limitations and ethics.                                                                                                                                                                              |
# | Documentation and written communication                                            | Code documentation is non-existent or perfunctory. Writing has usage errors, poor fluency, and poor rhetoric. If doc/writing are both like this you get unsatisfacory. If one is unsatisfactory and the other is developing you still get unsatisfactory overall.                                   | Code documentation is only partially there. Writing has some usage errors, some poor fluency, or some poor rhetoric. If doc/writing are both like this you get developing. If one is developing and the other is satisfactory you still get developing.                                                                             | Code is documented throughout. Writing has good fluency, good rhetoric, and at most a few minor errors.                                                                                                                                                       | Code documentation is highly informative with docstrings. Writing is high quality. If both doc/writing are like this you get excellent. If one is satisfactory and the other excellent you still get satisfactory.                                                                                                                                                |
# | Video (developing -1.5 points, unsatisfactory -3 points)                           | Video well outside the 3-5min time range. Does not communicate major results at a non-technical level. Has major technical issues such as no sound or not available at link. Unsatisfactory if 2/3 of these are true                                                                                | Video just outside the 3-5min time range. Does not communicate well on some points (either wrong tech level or just confusing). Has technical issues such as poor speech quality on video. Developing if 2/3 of these are true                                                                                                      | Video has good quality and is in within 3-5 min range. Communicates the major results at an accessible level for non-technical people.                                                                                                                        | Video has high production quality and is in within 3-5 min range. Communicates the major results clearly and gives a sense of the methods at an accessible level for non-technical people. Has a wow factor (e.g. funny or original approach)                                                                                                                     |
# | Quality modifier (can result in extra credit beyond 18 points for this assignment) | Almost everything was just barely proficient. Lots of minimal effort work. Do not double punish; if they already lost points on the rubric do not invoke this: -0.5 points                                                                                                                        |                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                       More than 5 excellents on this rubric: +0.5 points                                                                                   |

# %% [markdown]
# # COGS 108 - Final Project (change this to your project's title)
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [  ] YES - make available
# * [X] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# Immigration enforcement has become one of the most polarizing issues in the United States. With the passage of the One Big Beautiful Bill Act, making ICE the highest-funded federal law enforcement agency in the country, it is more important than ever to ask whether that investment actually translates to meaningful public safety outcomes.
# This study examines whether  ICE administrative arrest activity in Texas (N ≈ 90,000) is associated with reported rates of aggravated assault, robbery, rape, and murder during the same month or the following month (2019–2024). Using ICE arrest records from deportationdata.org and FBI UCR crime data, we computed Pearson correlation coefficients at same-month and one-month-lagged windows, conducted cross-correlation function (CCF) analysis across lags 0–6, and performed a sensitivity check excluding the COVID-19 period during which sharp fluctuations in both arrest volume and crime rates risked obscuring underlying trends. Our results indicate no statistically significant relationship between ICE arrest levels and violent crime counts at any lag (p > .05), consistent with the null hypothesis and prior research on the Secure Communities program. These findings suggest that variation in ICE enforcement intensity is not a meaningful predictor of short-term changes in violent crime in Texas.
# While the results do not establish causation, the high prevalence of non-felon arrests raises serious questions about the alignment between agency funding and the actual prioritization of high-level public safety threats.

# %% [markdown]
# ## Authors
#
# Sierra Peng: Conceptualization, Software, Data curation, Methodology, Writing - original draft, Analysis
#
# Dylan Nguyen: Project administration, Conceptualization, Software, Analysis, Writing - review & editing, Data Curation
#
# Juan Bello: Data curation, Methodology, Writing - original draft, Writing - review & editing
#
# Ellen Kwon: Conceptualization, Data curation, Methodology, Background research, Writing - original draft, Writing - review & editing
#
# Russel Wong: Writing - Data curation, original draft, Writing - review & editing

# %% [markdown]
# ## Research Question

# %% [markdown]
# Is there a statistically significant correlation between ICE arrests and reported rates of rape, murder, robbery, and assault in the same month or the following month in Texas from 2019 to 2024?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Immigration and Customs Enforcement (ICE) is a federal agency acting under the Department of Homeland Security. The main responsibilities of ICE include enforcing immigration law, preventing terrorism, and stopping illegal movement of people and goods within the United States.
#
# The motivation for exploring our topic lies in the dramatic increase in funding that ICE has received with the One Big Beautiful Bill Act. Prior to the passage of the One Big Beautiful Bill Act, ICE received about 10 dollars billion in budget per year. After passing, funding increased to 85 billion dollars. With the marked uptick in funding, activity, and media coverage, ICE has become a hotly contested topic for the American public in recent months, especially with notable incidents involving Renee Good and Alex Pretti. We will attempt to gain a better understanding of the efficacy of ICE on reducing violent and property crime.<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1)
#
# An article published in the The Journal of Law & Economics by Thomas J. Miles and Adam B. Cox examined the relationship between immigration enforcement and local US crime rates. The research specifically investigates the effect of the Secure Communities program. The Secure Communities program uses fingerprint-sharing between local law enforcement and federal immigration authorities to facilitate detention and removal of noncitizens. This is not a direct correlate to ICE, however, it may serve as a proxy to understand whether or not strict enforcement of immigration policy reduces crime. The conclusion of the study showed that the Secure Communities program led to hundreds of thousands of detentions, but did not reduce crime-rates as expected.<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2)
#
# The article Immigration and Customs Enforcement Raids the Pillar of a Community: Student Achievement, Absenteeism, and Mobility Following a Large Worksite Enforcement Operation in North Texas looks at the effects that ICE had through various time extents. It serves as a point of interest as to why Texas was chosen for this project, as well as a way to question what sort of empirical and statistical impact ICE had.<a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3)
#
# Of all states affected by ICE, Texas stands out in the number and scale of people detained. According to data from the Transactional Records Access Clearinghouse (TRAC) Immigration, there are 18,684 people in detention, as of January 22, 2026, which makes Texas the state with the most ICE detainees followed by Louisiana, 8,207 people, and California, 6,422. Geographically, Texas shares the longest border between the U.S. and Mexico, stretching 382 miles, with more than 40 border security stations across 5 sectors. The sheer size of the border and affiliated border control stations are key in understanding the subsequent size of detainees in Texas, which should be considered when examining the correlation between violent crime and ICE arrests. While Texas holds the greatest number of detainees, it is critical to understand that detention location is not the same as arrest location. Texas maintains some of the largest ICE detention centers in the country, where those arrested by ICE both in and out of Texas may be placed into. Therefore it is more representative to examine arrests per capita, to measure the presence of ICE in Texas independent from other states.<a name="cite_ref-4"></a>[<sup>4,</sup>](#cite_note-4)<a name="cite_ref-5"></a>[<sup>5</sup>](#cite_note-5)
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Chappell, Bill. “How ICE Grew to Be the Highest-Funded U.S. Law Enforcement Agency.” NPR, 21 Jan. 2026, www.npr.org/2026/01/21/nx-s1-5674887/ice-budget-funding-congress-trump.
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Miles, T. J., & Cox, A. B. (2014). Does Immigration Enforcement Reduce Crime? Evidence from Secure Communities. The Journal of Law and Economics, 57(4), 937–973. https://doi.org/10.1086/680935
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) J. Jacob Kirksey, and Carolyn Sattin-Bajaj. “Immigration and Customs Enforcement Raids the Pillar of a Community: Student Achievement, Absenteeism, and Mobility Following a Large Worksite Enforcement Operation in North Texas.” American Behavioral Scientist, 28 Nov. 2023, https://doi.org/10.1177/00027642231215992.
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4)U.S. Customs and Border Protection. (2025, n.d.). Border Patrol sectors. U.S. Department of Homeland Security. https://www.cbp.gov/border-security/along-us-borders/border-patrol-sectors
# 5. <a name="cite_note-5"></a> [^](#cite_ref-5)Transactional Records Access Clearinghouse. (2026). Immigration Quick Facts. https://tracreports.org/immigration/quickfacts/

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# There will be no statistically significant relationship between the level of ICE arrests in a given month and the rates of rape, murder, robbery, and aggravated assault reported in Texas during that **same month or the following month** (0-month and 1-month lag). We focus on same-month and one-month-lagged comparisons because administrative arrests are recorded at the time of apprehension; if enforcement activity deters crime, an effect would most plausibly appear within a short window. This hypothesis is consistent with prior research on the Secure Communities program, which found no significant crime-reduction effect despite large-scale detentions (Miles & Cox, 2014).

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# ## **Dataset #1**
# **Dataset Name:** ICE Administrative Arrests
# **Link to the dataset:** https://deportationdata.org/data/ice.html#historical-data-archive
# **Number of observations:** 89,848 (Texas)
# **Number of variables:** 23
#
# ### Descriptions of Variables
#   - We will primarily be looking at the apprehension date and time made by an ICE officer. These two variables can tell us which area a crime was happening and the time of someones aprehension. We are tracking this throughout 2019-2024.
#
# ### Shortcomings with respect to the project
# The ICE dataset does not give precise arrest locations. It is under a broad area or a landmark that are used inconsistently in the report. Being able to localize arrest location would help us have finer tracking when it comes to crime rate in certain areas and trying to connect it with arrests happening in similar areas.
#
#
# ## **Dataset #2**
# **Dataset Name:** Texas Crime Reports
# **Link to the dataset:** https://cde.ucr.cjis.gov/LATEST/webapp/#/pages/downloads
# **Number of observations:** 966799 (2019)
# **Number of variables:** 8
#
# ### Descriptions of Variables
#   - We will be looking at the number of violent offense types of crimes happening from 2019-2024. Our main variable will be how many offense types, more specifically violent offenses, happened that year. The crimes we tracked were counts of Rape, Murder and Nonnegligent Manslaughters, Robberies, and Aggravated Assaults. Our goal is to examine trends over time and determine whether increases or decreases in ICE activity are linked to changes in violent crime levels.
#
# ### Shortcomings with respect to the project
# Our main concern is that our data is aggregated at the state level and is not broken down by county or city. Because of this, we cannot examine regional variation within Texas. Any localized increases or decreases in violent crime may be hidden when looking at statewide totals. We are looking at pre and post Covid data. Irregularities wit policing patterns and crime might be common.
#
#
# ## **Dataset #3**
# **Dataset Name:** Texas Crime Reports, Monthly
# **Link to the dataset:** https://cde.ucr.cjis.gov/LATEST/webapp/#/pages/downloads
# **Number of observations:** 432
# **Number of variables:** 4
#
# ### Descriptions of Variables
#   - This dataset is included in order to examine crime rates on a more granular level. As opposed to the overall Crime Reports dataset, this dataset gives us access to crime data on a monthly basis. With this, we can compare it against ICE activity data to see whether ICE activity in one month has an effect on crime rates in subsequent months. The variables in this dataset are: Month, Offense, Outcome, and Count.
#
# ### Shortcomings with respect to the project
# Once again, this dataset does not provide more specific location information. Rather, it counts monthly crime for the entire state of Texas. It also includes pre and post Covid data.
#
# To see the code responsible for wrangling the data see `01-DataCheckpoint.ipynb`. From here on we will simply load the processed data for further analysis.

# %% [markdown]
# ### Dataset #1: ICE Administrative Arrests
#
# To see the code responsible for wrangling the data see `01-DataCheckpoint.ipynb`. From here on we will simply load the processed data for further analysis.

# %%
# ── Imports ───────────────────────────────────────────────────────────────
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.cm as cm
import seaborn as sns
from scipy import stats
from statsmodels.tsa.stattools import ccf

# ── Global plot style ──────────────────────────────────────────────────────
plt.rcParams['figure.dpi'] = 100
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False

# ── Constants ─────────────────────────────────────────────────────────────
CRIME_TYPES = [
    'Aggravated Assault',
    'Robbery',
    'Rape',
    'Murder and Nonnegligent Manslaughter'
]
CRIME_COLORS = ['#e41a1c', '#377eb8', '#ff7f00', '#4daf4a']
COVID_START = '2020-01-01'
COVID_END   = '2021-12-31'

# %%
# Load the saved clean ICE data
final_clean_ice = pd.read_csv('data/02-processed/ice_arrests_clean.csv')

# Data wrangling output cells
display(final_clean_ice.head())
print("Shape:", final_clean_ice.shape)
print("\nData Types:\n", final_clean_ice.dtypes)
print("\nNull Counts:\n", final_clean_ice.isnull().sum())
print("\nNull Proportions:\n", final_clean_ice.isnull().mean().round(4))
print("\nArrests by Year:\n", pd.to_datetime(final_clean_ice['Apprehension Date And Time']).dt.year.value_counts().sort_index())
print("\nArrests by Texas AOR:\n", final_clean_ice['Apprehension AOR'].value_counts())
print("\nMost Serious Crime Class:\n", final_clean_ice['Most Serious Crime Class'].value_counts())
print("\nNumber of duplicate rows:", final_clean_ice.duplicated().sum(), "| Therefore each row represents a single arrest")

missing_apprehensions = final_clean_ice['Apprehension Date And Time'].isna().sum()
print("\nRows missing apprehension timestamp:", missing_apprehensions)

parsed_dates = pd.to_datetime(
    final_clean_ice['Apprehension Date And Time'],
    errors='coerce'
)

invalid_dates = parsed_dates.isna().sum()
print("Invalid apprehension timestamps:", invalid_dates)

print("Total rows:", len(final_clean_ice))
print("Total valid apprehension timestamps:", parsed_dates.notna().sum())
# Out:
#                 Apprehension AOR Apprehension Date And Time  \
# 0  Dallas Area of Responsibility        2019-03-07 08:22:00
# 1  Dallas Area of Responsibility        2019-01-07 10:32:00
# 2  Dallas Area of Responsibility        2019-01-07 10:22:00
# 3  Dallas Area of Responsibility        2019-05-02 09:38:00
# 4  Dallas Area of Responsibility        2019-05-19 09:43:00
#
#   Most Serious Crime Class
# 0              Misdemeanor
# 1              Misdemeanor
# 2              Misdemeanor
# 3                   Felony
# 4              Misdemeanor
# Shape: (199617, 3)
#
# Data Types:
#  Apprehension AOR              object
# Apprehension Date And Time    object
# Most Serious Crime Class      object
# dtype: object
#
# Null Counts:
#  Apprehension AOR              0
# Apprehension Date And Time    0
# Most Serious Crime Class      0
# dtype: int64
#
# Null Proportions:
#  Apprehension AOR              0.0
# Apprehension Date And Time    0.0
# Most Serious Crime Class      0.0
# ...

# %% [markdown]
# ### Dataset #2: Texas Crime Reports

# %%
# Load the saved clean crime data
texas_offenses_all = pd.read_csv('data/02-processed/texas_offenses_clean.csv')

display(texas_offenses_all.head())

# Data wrangling output cells
print("Shape:", texas_offenses_all.shape)
print("\nData Types:\n", texas_offenses_all.dtypes)
print("\nNull Counts:\n", texas_offenses_all.isnull().sum())
print("\nNull Proportions:\n", texas_offenses_all.isnull().mean().round(4))
print("\nOffenses by Year:\n", texas_offenses_all['data_year'].value_counts().sort_index())
print("\nOffense Type Breakdown:\n", texas_offenses_all['offense_code'].value_counts())
print("\nOffense Type by Year:")
print(pd.crosstab(texas_offenses_all['data_year'], texas_offenses_all['offense_code']))

print(f"\nNumber of unique rows in offense_id: {texas_offenses_all['offense_id'].nunique()} | This matches the number of rows in the dataset, therefore, each row is an offense.")
# Out:
#    data_year        offense_code  offense_id
# 0       2019  Aggravated Assault   138373905
# 1       2019  Aggravated Assault   138384764
# 2       2019  Aggravated Assault   138375422
# 3       2019             Robbery   138386805
# 4       2019  Aggravated Assault   138386979
# Shape: (583834, 3)
#
# Data Types:
#  data_year        int64
# offense_code    object
# offense_id       int64
# dtype: object
#
# Null Counts:
#  data_year       0
# offense_code    0
# offense_id      0
# dtype: int64
#
# Null Proportions:
#  data_year       0.0
# offense_code    0.0
# offense_id      0.0
# dtype: float64
#
# Offenses by Year:
#  data_year
# 2019     67504
# 2020     91819
# 2021    109716
# 2022    107830
# 2023    104051
# 2024    102914
# Name: count, dtype: int64
#
# Offense Type Breakdown:
#  offense_code
# Aggravated Assault                      388490
# Robbery                                 128825
# Rape                                     57230
# ...

# %% [markdown]
# ### Dataset #3: Texas Crime Reports, Monthly

# %%
# Load the saved clean crime data
texas_offenses_all_monthly = pd.read_csv('data/02-processed/texas_offenses_monthly_clean.csv')
display(texas_offenses_all_monthly.head())
print('Each row represents the monthly count for a particular offense type.\n')

# Data wrangling output cells
print("Shape:", texas_offenses_all_monthly.shape)
print("\nData Types:\n", texas_offenses_all_monthly.dtypes)
print("\nNull Counts:\n", texas_offenses_all_monthly.isnull().sum())
print("\nNull Proportions:\n", texas_offenses_all_monthly.isnull().mean().round(4))

# Convert Month column to datetime
texas_offenses_all_monthly['Month'] = pd.to_datetime(texas_offenses_all_monthly['Month'])

# Offenses by year (total)
offenses_by_year = texas_offenses_all_monthly.groupby(
    texas_offenses_all_monthly['Month'].dt.year
)['Count'].sum().astype(int)
offenses_by_year.index.name = 'Year'

print("\nOffenses by Year:\n", offenses_by_year)

# Offense type breakdown (total across all months)
offense_type_total = texas_offenses_all_monthly.groupby('Offense')['Count'].sum().astype(int)
print("\nOffense Type Breakdown:\n", offense_type_total)

# Offense type by year
offense_by_year = texas_offenses_all_monthly.groupby(
    [texas_offenses_all_monthly['Month'].dt.year, 'Offense']
)['Count'].sum().unstack(fill_value=0).astype(int)
offense_by_year.index.name = 'Year'

print("\nOffense Type by Year:")
print(offense_by_year)
# Out:
#         Month             Offense    Outcome   Count
# 0  2019-01-01  Aggravated Assault  Completed  3347.0
# 1  2019-02-01  Aggravated Assault  Completed  2997.0
# 2  2019-03-01  Aggravated Assault  Completed  3838.0
# 3  2019-04-01  Aggravated Assault  Completed  3706.0
# 4  2019-05-01  Aggravated Assault  Completed  4375.0
# Each row represents the monthly count for a particular offense type.
#
# Shape: (432, 4)
#
# Data Types:
#  Month       object
# Offense     object
# Outcome     object
# Count      float64
# dtype: object
#
# Null Counts:
#  Month      0
# Offense    0
# Outcome    0
# Count      0
# dtype: int64
#
# Null Proportions:
#  Month      0.0
# Offense    0.0
# Outcome    0.0
# Count      0.0
# dtype: float64
#
# Offenses by Year:
#  Year
# 2019     78805
# 2020    107974
# 2021    129587
# 2022    127903
# 2023    122292
# 2024    119882
# Name: Count, dtype: int64
#
# Offense Type Breakdown:
#  Offense
# Aggravated Assault                      481277
# ...

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# After data wrangling we have three cleaned datasets: `ice_arrests_clean` (199,617 Texas ICE arrests), `texas_offenses_clean` (583,834 individual offense records), and `texas_offenses_monthly_clean` (432 monthly offense totals). The EDA below is organized around our hypothesis — specifically whether ICE arrest counts in a given month are associated with violent crime counts in the same or following month.
#
# This EDA is structured in four sections:
# * **Section 1** — Baseline trends: ICE arrests and each crime type over time, with COVID period highlighted.
# * **Section 2** — Annual correlation: scatter plots with and without the COVID period, plus a summary correlation table.
# * **Section 3** — Monthly lag analysis: rolling averages, year-by-month seasonality plots, lag structure visualization, and lagged scatter plots.
# * **Section 4** — Additional ICE variables: crime class distribution by year and arrests by Area of Responsibility.

# %% [markdown]
# #### Section 1A — Baseline Trends: ICE Arrests and Crime Over Time
#
# This section will first look into the temporal trends of each dataset individually to get an idea of the distribution of each dataset before they are analyzed together. Figure 1A will display ICE arrests over time with a 3-month rolling average to smooth out the curve, while figure 2A will display crimes commited over time, divided into types of crime, being Aggravated Assault, Robbery, Rape, and Murder and Non-negligent Manslaughter. These graphs will also include a highlighted portion to denote years that are considered COVID years.

# %%
# ── Create figures directory ──────────────────────────────────────────────
import os
os.makedirs('figures', exist_ok=True)

# ── Load data ─────────────────────────────────────────────────────────────
ice_df = pd.read_csv('data/02-processed/ice_arrests_clean.csv')
ice_df['datetime'] = pd.to_datetime(ice_df['Apprehension Date And Time'])

crime_df     = pd.read_csv('data/02-processed/texas_offenses_clean.csv')
monthly_df   = pd.read_csv('data/02-processed/texas_offenses_monthly_clean.csv')
monthly_df['Month'] = pd.to_datetime(monthly_df['Month'])
# Use completed offenses only
monthly_df = monthly_df[monthly_df['Outcome'] == 'Completed'].copy()

# ── 1A: Monthly ICE arrests + rolling average ─────────────────────────────
monthly_ice = ice_df.set_index('datetime').resample('ME').size()
rolling_ice = monthly_ice.rolling(3, center=True).mean()

fig, ax = plt.subplots(figsize=(11, 4))
ax.fill_between(
    pd.date_range(COVID_START, COVID_END, freq='D'), 0, monthly_ice.max() * 1.1,
    color='gold', alpha=0.25, label='COVID-19 period (2020–2021)'
)
ax.plot(monthly_ice.index, monthly_ice.values, color='steelblue', alpha=0.35, linewidth=1, label='Monthly arrests')
ax.plot(rolling_ice.index, rolling_ice.values, color='steelblue', linewidth=2.2, label='3-month rolling avg')
ax.set_xlabel('Date')
ax.set_ylabel('ICE Arrests')
ax.set_title('Fig 1A — Monthly ICE Administrative Arrests in Texas (2019–2024)')
ax.legend(fontsize=9)
ax.set_ylim(0)
plt.tight_layout()
plt.savefig('figures/fig1a_ice_monthly.png', bbox_inches='tight')
plt.show()
print(f"Total arrests 2019–2024: {len(ice_df):,}")
print(f"Peak month: {monthly_ice.idxmax().strftime('%b %Y')} ({monthly_ice.max():,.0f} arrests)")
print(f"Trough month: {monthly_ice.idxmin().strftime('%b %Y')} ({monthly_ice.min():,.0f} arrests)")
# Out:
# Total arrests 2019–2024: 199,617
# Peak month: Oct 2022 (4,489 arrests)
# Trough month: Sep 2024 (0 arrests)

# %% [markdown]
# ADD SOME DESCRIPTION HERE

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8), sharex=True)
axes = axes.flatten()

for ax, crime_type, color in zip(axes, CRIME_TYPES, CRIME_COLORS):
    subset = crime_df[crime_df['offense_code'] == crime_type]
    yearly = subset.groupby('data_year').size()
    # shade COVID years
    ax.axvspan(2020 - 0.4, 2021 + 0.4, color='gold', alpha=0.25, label='COVID-19')
    ax.plot(yearly.index, yearly.values, color=color, marker='o', linewidth=2)
    ax.set_title(crime_type, fontsize=10, fontweight='bold')
    ax.set_xlabel('Year')
    ax.set_ylabel('Offense Count')
    ax.set_xticks(range(2019, 2025))

    peak_year = yearly.idxmax()
    peak_val = yearly.max()
    trough_year = yearly.idxmin()
    trough_val = yearly.min()

    print(f"--- {crime_type} ---")
    print(f"Peak:   {peak_year} ({peak_val} arrests)")
    print(f"Trough: {trough_year} ({trough_val} arrests)\n")

axes[0].legend(fontsize=8)
plt.suptitle('Fig 1B — Annual Violent Crime Counts in Texas (2019–2024)', fontsize=13, y=1.01)
plt.tight_layout()
plt.savefig('figures/fig1b_crime_annual.png', bbox_inches='tight')
plt.show()
# Out:
# --- Aggravated Assault ---
# Peak:   2021 (74598 arrests)
# Trough: 2019 (39900 arrests)
#
# --- Robbery ---
# Peak:   2020 (23329 arrests)
# Trough: 2024 (19926 arrests)
#
# --- Rape ---
# Peak:   2024 (11204 arrests)
# Trough: 2019 (5916 arrests)
#
# --- Murder and Nonnegligent Manslaughter ---
# Peak:   2021 (1908 arrests)
# Trough: 2019 (838 arrests)

# %% [markdown]
# DESCRIPTION HERE

# %% [markdown]
# #### Section 2 — Annual Correlation Between ICE Arrests and Crime by Year
#
# This section will display the correlation between ICE arrests and crime by type over years. COVID years will be denoted by yellow points. The calculated r and p values denote that although there is a negative relationship between ICE arrests and reported crime, there is no statistical correlation between the two, even after excluding COVID years to account for confounding variables.

# %%
# Build annual summary table
ice_df['year'] = ice_df['datetime'].dt.year
ice_yearly = ice_df.groupby('year').size().rename('ice_arrests')

annual_rows = []
for crime_type in CRIME_TYPES:
    subset = crime_df[crime_df['offense_code'] == crime_type]
    crime_yearly = subset.groupby('data_year').size().rename('crime_count')
    combined = pd.DataFrame({'ice_arrests': ice_yearly, 'crime_count': crime_yearly}).dropna()
    r_full, p_full = stats.pearsonr(combined['ice_arrests'], combined['crime_count'])
    # exclude COVID years
    combined_nc = combined[~combined.index.isin([2020, 2021])]
    if len(combined_nc) >= 3:
        r_nc, p_nc = stats.pearsonr(combined_nc['ice_arrests'], combined_nc['crime_count'])
    else:
        r_nc, p_nc = float('nan'), float('nan')
    annual_rows.append({
        'Crime Type': crime_type,
        'r (full)': round(r_full, 3),
        'p (full)': round(p_full, 3),
        'r (excl. COVID)': round(r_nc, 3) if not np.isnan(r_nc) else '—',
        'p (excl. COVID)': round(p_nc, 3) if not np.isnan(p_nc) else '—',
    })

corr_table = pd.DataFrame(annual_rows)
print("Table 1 — Annual Pearson Correlations: ICE Arrests vs. Violent Crime")
print(corr_table.to_string(index=False))

# Scatter plot grid
fig, axes = plt.subplots(2, 2, figsize=(12, 9))
axes = axes.flatten()

for ax, crime_type, color in zip(axes, CRIME_TYPES, CRIME_COLORS):
    subset = crime_df[crime_df['offense_code'] == crime_type]
    crime_yearly = subset.groupby('data_year').size().rename('crime_count')
    combined = pd.DataFrame({'ice_arrests': ice_yearly, 'crime_count': crime_yearly}).dropna()

    covid_mask = combined.index.isin([2020, 2021])
    ax.scatter(combined.loc[~covid_mask, 'ice_arrests'], combined.loc[~covid_mask, 'crime_count'],
               color=color, s=80, zorder=3, label='Non-COVID years')
    ax.scatter(combined.loc[covid_mask, 'ice_arrests'], combined.loc[covid_mask, 'crime_count'],
               color='gold', edgecolors='gray', s=80, zorder=3, label='COVID years (2020–21)')

    # regression line (full period)
    m, b, *_ = stats.linregress(combined['ice_arrests'], combined['crime_count'])
    x_line = np.linspace(combined['ice_arrests'].min(), combined['ice_arrests'].max(), 100)
    ax.plot(x_line, m * x_line + b, color='gray', linestyle='--', linewidth=1.2, label='OLS (full)')

    for year, row in combined.iterrows():
        ax.annotate(str(year), (row['ice_arrests'], row['crime_count']),
                    fontsize=8, ha='right', va='bottom')

    row_data = corr_table[corr_table['Crime Type'] == crime_type].iloc[0]
    ax.set_title(f"{crime_type}\nr={row_data['r (full)']} (full), r={row_data['r (excl. COVID)']} (no COVID)", fontsize=9)
    ax.set_xlabel('Annual ICE Arrests')
    ax.set_ylabel('Annual Offense Count')
    ax.legend(fontsize=7)

plt.suptitle('Fig 2 — Annual ICE Arrests vs. Violent Crime (2019–2024)', fontsize=13, y=1.01)
plt.tight_layout()
plt.savefig('figures/fig2_annual_scatter.png', bbox_inches='tight')
plt.show()
# Out:
# Table 1 — Annual Pearson Correlations: ICE Arrests vs. Violent Crime
#                           Crime Type  r (full)  p (full)  r (excl. COVID)  p (excl. COVID)
#                   Aggravated Assault    -0.388     0.447           -0.315            0.685
#                              Robbery    -0.352     0.494            0.938            0.062
#                                 Rape    -0.298     0.566           -0.421            0.579
# Murder and Nonnegligent Manslaughter    -0.387     0.448           -0.103            0.897

# %% [markdown]
# #### Section 3 — Monthly Analysis: Seasonality, Rolling Averages, and Lag Structure

# %%
# ── 3A: Year-by-month seasonality plots ───────────────────────────────────
import matplotlib.cm as cm

fig, axes = plt.subplots(2, 2, figsize=(14, 9))
axes = axes.flatten()

for ax, crime_type, base_color in zip(axes, CRIME_TYPES, CRIME_COLORS):
    subset = monthly_df[monthly_df['Offense'] == crime_type].copy()
    monthly_totals = subset.groupby('Month')['Count'].sum().reset_index()
    monthly_totals['year'] = monthly_totals['Month'].dt.year
    monthly_totals['month_num'] = monthly_totals['Month'].dt.month

    years = sorted(monthly_totals['year'].unique())
    cmap = cm.get_cmap('Blues', len(years) + 2)
    colors_yr = [cmap(i + 2) for i in range(len(years))]
    month_labels = ['J','F','M','A','M','J','J','A','S','O','N','D']

    for yr, c in zip(years, colors_yr):
        yr_data = monthly_totals[monthly_totals['year'] == yr].sort_values('month_num')
        lw = 2.5 if yr not in [2020, 2021] else 1.2
        ls = '-' if yr not in [2020, 2021] else '--'
        ax.plot(yr_data['month_num'], yr_data['Count'], color=c, linewidth=lw,
                linestyle=ls, marker='o', markersize=3, label=str(yr))

    ax.set_xticks(range(1, 13))
    ax.set_xticklabels(month_labels)
    ax.set_title(crime_type, fontsize=10, fontweight='bold')
    ax.set_xlabel('Month')
    ax.set_ylabel('Completed Offenses')
    ax.legend(fontsize=7, ncol=2)

plt.suptitle('Fig 3 — Violent Crime by Calendar Month, Each Year (2019–2024)\n(dashed = COVID years)', fontsize=12, y=1.01)
plt.tight_layout()
plt.savefig('figures/fig3_seasonality.png', bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_2496/4005821040.py:14: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('Blues', len(years) + 2)
# /tmp/ipykernel_2496/4005821040.py:14: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('Blues', len(years) + 2)
# /tmp/ipykernel_2496/4005821040.py:14: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('Blues', len(years) + 2)
# ...

# %% [markdown]
# Description here

# %%
# ── 3B: Lag structure — CCF for each crime type ──────────────────────────
from statsmodels.tsa.stattools import ccf as sm_ccf

# Build monthly aligned series
monthly_ice_series = ice_df.set_index('datetime').resample('ME').size()
monthly_ice_series.index = monthly_ice_series.index.to_period('M').to_timestamp()

fig, axes = plt.subplots(2, 2, figsize=(13, 8))
axes = axes.flatten()

MAX_LAG = 8
sig_level = 1.96 / np.sqrt(len(monthly_ice_series))  # ~95% CI band

for ax, crime_type, color in zip(axes, CRIME_TYPES, CRIME_COLORS):
    subset = monthly_df[monthly_df['Offense'] == crime_type]
    crime_series = subset.groupby('Month')['Count'].sum()
    crime_series.index = pd.to_datetime(crime_series.index).to_period('M').to_timestamp()

    merged = pd.DataFrame({
        'ice': monthly_ice_series,
        'crime': crime_series
    }).dropna()

    # Cross-correlation: positive lag k means crime at t+k vs ice at t
    ccf_vals = sm_ccf(merged['ice'], merged['crime'], nlags=MAX_LAG, adjusted=False)

    lags = np.arange(len(ccf_vals))
    ax.bar(lags, ccf_vals, color=[color if abs(v) > sig_level else 'lightgray' for v in ccf_vals])
    ax.axhline(sig_level,  color='black', linestyle='--', linewidth=0.9, label='95% CI')
    ax.axhline(-sig_level, color='black', linestyle='--', linewidth=0.9)
    ax.axhline(0, color='black', linewidth=0.5)
    ax.set_xticks(lags)
    ax.set_xlabel('Lag (months)')
    ax.set_ylabel('Cross-correlation')
    ax.set_title(crime_type, fontsize=10, fontweight='bold')
    ax.legend(fontsize=7)
    ax.set_ylim(-0.6, 0.6)

plt.suptitle('Fig 4 — Cross-Correlation: ICE Arrests (t) vs. Crime Count (t + lag)', fontsize=12, y=1.01)
plt.tight_layout()
plt.savefig('figures/fig4_ccf.png', bbox_inches='tight')
plt.show()
print(f"95% significance band: ±{sig_level:.3f}")
# Out:
# 95% significance band: ±0.231

# %% [markdown]
# Description here

# %%
# ── 3C: Formal Pearson tests — lag 0 and lag 1 ───────────────────────────
monthly_ice_df = monthly_ice_series.reset_index()
monthly_ice_df.columns = ['Month', 'ice_arrests']

results = []

for lag in [0, 1, 2]:
    for crime_type in CRIME_TYPES:
        subset = monthly_df[monthly_df['Offense'] == crime_type]
        crime_monthly = subset.groupby('Month')['Count'].sum().reset_index()
        crime_monthly.columns = ['Month', 'crime_count']

        # Shift crime forward by lag (crime at t+lag vs ice at t)
        crime_monthly_shifted = crime_monthly.copy()
        crime_monthly_shifted['Month'] = crime_monthly_shifted['Month'] - pd.DateOffset(months=lag)

        merged = pd.merge(monthly_ice_df, crime_monthly_shifted, on='Month')

        r, p = stats.pearsonr(merged['ice_arrests'], merged['crime_count'])
        results.append({
            'Crime Type': crime_type,
            'Lag (months)': lag,
            'n': len(merged),
            'r': round(r, 3),
            'p-value': round(p, 4),
            'Significant (p<0.05)': 'Yes' if p < 0.05 else 'No'
        })

results_df = pd.DataFrame(results)
print("Table 2 — Monthly Pearson Correlations: ICE Arrests vs. Violent Crime")
print(results_df.to_string(index=False))
# Out:
# Table 2 — Monthly Pearson Correlations: ICE Arrests vs. Violent Crime
#                           Crime Type  Lag (months)  n      r  p-value Significant (p<0.05)
#                   Aggravated Assault             0 72 -0.271   0.0213                  Yes
#                              Robbery             0 72 -0.076   0.5276                   No
#                                 Rape             0 72 -0.236   0.0458                  Yes
# Murder and Nonnegligent Manslaughter             0 72 -0.194   0.1019                   No
#                   Aggravated Assault             1 71 -0.335   0.0043                  Yes
#                              Robbery             1 71 -0.105   0.3821                   No
#                                 Rape             1 71 -0.303   0.0102                  Yes
# Murder and Nonnegligent Manslaughter             1 71 -0.302   0.0105                  Yes
# ...

# %% [markdown]
# Description here

# %%
# ── 3D: Sensitivity — exclude COVID months (2020–2021) ───────────────────
covid_months = pd.date_range('2020-01-01', '2021-12-01', freq='MS')

sensitivity_results = []

for lag in [0, 1]:
    for crime_type in CRIME_TYPES:
        subset = monthly_df[monthly_df['Offense'] == crime_type]
        crime_monthly = subset.groupby('Month')['Count'].sum().reset_index()
        crime_monthly.columns = ['Month', 'crime_count']

        crime_monthly_shifted = crime_monthly.copy()
        crime_monthly_shifted['Month'] = crime_monthly_shifted['Month'] - pd.DateOffset(months=lag)

        merged = pd.merge(monthly_ice_df, crime_monthly_shifted, on='Month')
        # Exclude COVID period
        merged_nc = merged[~merged['Month'].isin(covid_months)]

        r_full, p_full = stats.pearsonr(merged['ice_arrests'], merged['crime_count'])
        r_nc, p_nc = stats.pearsonr(merged_nc['ice_arrests'], merged_nc['crime_count'])

        sensitivity_results.append({
            'Crime Type': crime_type,
            'Lag': lag,
            'r (full)': round(r_full, 3),
            'p (full)': round(p_full, 4),
            'r (no COVID)': round(r_nc, 3),
            'p (no COVID)': round(p_nc, 4),
        })

sens_df = pd.DataFrame(sensitivity_results)
print("Table 3 — Sensitivity Analysis: Full Period vs. Excluding COVID (2020–2021)")
print(sens_df.to_string(index=False))
# Out:
# Table 3 — Sensitivity Analysis: Full Period vs. Excluding COVID (2020–2021)
#                           Crime Type  Lag  r (full)  p (full)  r (no COVID)  p (no COVID)
#                   Aggravated Assault    0    -0.271    0.0213        -0.150        0.3073
#                              Robbery    0    -0.076    0.5276         0.155        0.2918
#                                 Rape    0    -0.236    0.0458        -0.274        0.0599
# Murder and Nonnegligent Manslaughter    0    -0.194    0.1019        -0.078        0.5984
#                   Aggravated Assault    1    -0.335    0.0043        -0.190        0.2018
#                              Robbery    1    -0.105    0.3821         0.129        0.3889
#                                 Rape    1    -0.303    0.0102        -0.278        0.0584
# Murder and Nonnegligent Manslaughter    1    -0.302    0.0105        -0.141        0.3439

# %% [markdown]
# Description here

# %% [markdown]
# #### Section 4 — Additional ICE Variables

# %%
# ── 4A: Crime class distribution by year ─────────────────────────────────
ice_df['year'] = ice_df['datetime'].dt.year
crime_class_by_year = (
    ice_df.groupby(['year', 'Most Serious Crime Class'])
    .size()
    .unstack(fill_value=0)
)
# Normalize to proportions
crime_class_pct = crime_class_by_year.div(crime_class_by_year.sum(axis=1), axis=0) * 100

order = ['Felony', 'Aggravated Felony', 'Misdemeanor', 'Other', 'Not Applicable', 'Not Reported']
order = [c for c in order if c in crime_class_pct.columns]
crime_class_pct = crime_class_pct[order]

ax = crime_class_pct.plot(kind='bar', stacked=True, figsize=(10, 5),
                          colormap='tab10', edgecolor='white', linewidth=0.5)
ax.set_xlabel('Year')
ax.set_ylabel('Proportion of Arrests (%)')
ax.set_title('Fig 5 — Most Serious Crime Class of ICE Arrestees in Texas, by Year')
ax.set_xticklabels(crime_class_pct.index, rotation=0)
ax.legend(title='Crime Class', bbox_to_anchor=(1.01, 1), loc='upper left', fontsize=9)
plt.tight_layout()
plt.savefig('figures/fig5_crime_class.png', bbox_inches='tight')
plt.show()

print("\nOverall crime class breakdown:")
overall = ice_df['Most Serious Crime Class'].value_counts()
print((overall / overall.sum() * 100).round(1).to_string())
# Out:
# Overall crime class breakdown:
# Most Serious Crime Class
# Misdemeanor          37.2
# Not Reported         28.3
# Felony               25.8
# Aggravated Felony     7.1
# Other                 1.4
# Not Applicable        0.3

# %% [markdown]
# This graph displays the distribution of the most serious crime type an ICE arrestee had committed, sectioned into each year. As it stands, there is a significant portion of unreported data.

# %%
# ── 4B: Monthly ICE arrests by AOR with rolling averages ─────────────────
monthly_aor = (
    ice_df
    .groupby([pd.Grouper(key='datetime', freq='ME'), 'Apprehension AOR'])
    .size()
    .unstack(fill_value=0)
)
monthly_aor.columns = [c.replace(' Area of Responsibility', '') for c in monthly_aor.columns]

fig, ax = plt.subplots(figsize=(12, 5))
aor_colors = ['#e41a1c','#377eb8','#ff7f00','#4daf4a','#984ea3']

for aor, color in zip(monthly_aor.columns, aor_colors):
    raw = monthly_aor[aor]
    roll = raw.rolling(3, center=True).mean()
    ax.plot(monthly_aor.index, raw, alpha=0.15, color=color)
    ax.plot(monthly_aor.index, roll, color=color, linewidth=2, label=aor)

ax.axvspan(pd.Timestamp(COVID_START), pd.Timestamp(COVID_END),
           color='gold', alpha=0.2, label='COVID-19 period')
ax.set_xlabel('Date')
ax.set_ylabel('ICE Arrests (3-month rolling avg)')
ax.set_title('Fig 6 — Monthly ICE Arrests by Texas Area of Responsibility')
ax.legend(bbox_to_anchor=(1.01, 1), loc='upper left', fontsize=8)
plt.tight_layout()
plt.savefig('figures/fig6_aor.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# This figure displays the monthly ICE arrests over a 3-month rolling average divided by areas of responsibility. Additionally, there are highlighted ares to stop signify COVID years, similar to figures 1A, and 1B. It should be noted that as certain areas of responsibility cover a larger population, the graph is not necessarily indicative of certain trends outright.

# %%
# ── 4C: Dual y-axis overlay ───────────────────────────────────────────────
total_monthly_crime = monthly_df.groupby('Month')['Count'].sum()

fig, ax1 = plt.subplots(figsize=(12, 5))

ax1.fill_between(
    pd.date_range(COVID_START, COVID_END, freq='D'), 0, 12000,
    color='gold', alpha=0.2, label='COVID-19 period'
)
ax1.plot(monthly_ice.index, monthly_ice.rolling(3, center=True).mean(),
         color='steelblue', linewidth=2, label='ICE arrests (3-mo avg)')
ax1.set_xlabel('Date')
ax1.set_ylabel('ICE Arrests', color='steelblue')
ax1.tick_params(axis='y', labelcolor='steelblue')
ax1.set_ylim(0, 12000)

ax2 = ax1.twinx()
ax2.plot(total_monthly_crime.index, total_monthly_crime.rolling(3, center=True).mean(),
         color='crimson', linewidth=2, linestyle='--', label='Total violent crime (3-mo avg)')
ax2.set_ylabel('Total Violent Crimes', color='crimson')
ax2.tick_params(axis='y', labelcolor='crimson')
ax2.set_ylim(0, 12000)

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left', fontsize=9)

plt.title('Fig 7 — Monthly ICE Arrests vs. Total Violent Crime in Texas (3-Month Rolling Avg)')
plt.tight_layout()
plt.savefig('figures/fig7_overlay.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# This graph displays a relationship between ICE arrests (monthly), and total violent crime (3-mo. rolling average). While there seems to be a negative relationship between the two throughout the COVID years, if we exclude them it shows no significant relationship.

# %% [markdown]
# ### ETC AD NASEUM
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# ## Ethics

# %% [markdown]
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# There could be some sources of bias in our data, for example since the ICE arrest records come from ICE themselves, we do not know if they choose to leave certain arrests unrecorded. The same type of bias also applies to the data of crime rate, since some crimes may go unrecorded. Also, there could be bias in the way that the data was recorded across different areas, for instance some places could be more strict in what they record than others.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# The data we are using does not use personally identifiable information.  The data sources has encrypted any identifying documents. We still have data about demographics and location, but people’s personal information is safe.
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# The methods used in this project should be able to be applied on data collected in the future so long as the formatting of data is similar.
#
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
# Since our data was obtained from reputable open sources, the danger of exposing personal information was extremely minimal. While encryption at rest and in transit is not applicable, our data will be stored on the private team project repository only accessible by invited members on Github. Any changes to our data will be recorded by version control, to minimize accidental deletion or modifications.
#
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# Data will only be accessed during the progression of the project and later deleted from our local systems upon completion. The data will exist in the Github repository with no plan to delete it for future academic purposes.
#
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
# We plan on making sure that we do not reinforce harmful stereotypes by discussing amongst each other as well as reaching out to those in affected communities
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# We are aware of the possibilities of misreporting statistics and other variables and will try to account for this error
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
# We will only present what the data shows and not draw any unnecessary conclusions.
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
# This data doesn't use personally identifiable information. In case we come across this, we will not display any unnecessary data that may break privacy.
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# We will document our process of analysis with explanations of our findings. The documentation of our analysis will include every step we took to analyze the data so that it will be reproducible in the future.
#
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
# We recognize that the two main variables of our study, ICE arrests and criminal offenses per capita, are closely intertwined with historically discriminatory socio-economic factors. While the data may reflect systemic discriminatory bias, we do not believe the data itself is unfairly discriminatory. Our project works to analyze the hypothesized cross-over between two groups of people, those arrested by ICE and those who have committed a criminal offense.
#
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#
# As previously mentioned, we recognize that data regarding criminal offenses and ICE arrests exist within a socio-economic and political context. The criminal justice system disproportionately affects marginalized communities, which will be reflected in released datasets. As a group, we will analyze our findings with this in mind, knowing that the representation of people groups within the two categories of criminal offenses and ICE arrests are not reflective of a just system.
#
#  - [ ] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#
# In regards to decisions made by the model, we will describe findings through a combination of diagrams and clearly outlined explanations. Explanations will include relevant variables and necessary context to ensure understanding.
#
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
#  It's stated that this model only measures the relationship between Texas crime per capita and ICE arrests per capita, so the model is only limited to this scope and has been communicated as such.
#
# ### E. Deployment
#  - [ ] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#
# There is a plan to monitor the downstream impacts as well as to regularly check to verify the accuracy of the model.
#
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#
# It's been discussed on how to evaluate the potential harm that this model can do and measures have been taken in order to update the model if need be.
#
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#
# Because the data from the Texas crime reports and ICE arrests are divided by year, we can remove newer data if needed and re-run the data wrangling in order to rollback the model. Furthermore, there are systems in place to turn off the model if necessary.
#
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# There is no way to fully cover this models misuse. However, there have been steps taken in the Research Question, Background Work, and Hypothesis to try and prevent it. Furthermore, there are plans to monitor the effects of this model after it has been deployed.

# %% [markdown]
# ## Discusison and Conclusion
#
# Wrap it all up here.  Somewhere between 3 and 10 paragraphs roughly.
# 1. Summarize the important results you made
# 2. This is a good time to refer back to your Background section and review how this work extended the previous stuff.
# 3. Try to bring all the different results together into a bigger picture... what have we learned?
# 4. Often what we learned is confusing.  Discuss if there are contradictory results how that might have happened
# 5. Discuss the limitations of your work. e.g, is the dataset a biased sample? would more data make you more confident? would longitudinal instead of cross-sectional data helpful? is there evidence that the phenomena you're investigating may change over time? etc
# 6. If you would like, you can also say what the next steps in this investigation might be if the work was to continue outside this class
